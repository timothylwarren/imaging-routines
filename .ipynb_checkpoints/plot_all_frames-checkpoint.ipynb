# %%
ls
# Out:
# Untitled.ipynb               make_movie2pa.py
# Untitled1.ipynb              old_files/
# another_roi_example.py       plot_all_frames_of_a_tif.py
# example_data/                plot_example_time_course.py
# make_images_for_video.py

# %%
# %matplotlib inline

# %%
run plot_all_frames_of_a_tif.py
